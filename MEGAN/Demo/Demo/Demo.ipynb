# %%
import librosa
import IPython.display as ipd

# %% [markdown]
# ### MEGAN trained on Gaussian noise

# %% [markdown]
# #### Noise

# %%
y_gaus_b, sr_gaus_b = librosa.load('./Output/Gaussian/DiffNoiseGanBefore.wav')

# %%
ipd.Audio(y_gaus_b,rate = sr_gaus_b)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Output

# %%
y_gaus_a, sr_gaus_a = librosa.load('./Output/Gaussian/DiffNoiseGanAfter.wav')

# %%
ipd.Audio(y_gaus_a,rate = sr_gaus_a)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Epoch 110 for MEGAN trained on Concert Noise

# %% [markdown]
# #### Concert Noise

# %%
y_noise, sr_noise = librosa.load('./Output/noise.wav')

# %%
ipd.Audio(y_noise,rate = sr_noise)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Example 1

# %% [markdown]
# #### Original

# %%
y_O,sr_O = librosa.load('./Output/Noisy_dig110/original_dig_110_Final.wav')

# %%
ipd.Audio(y_O,rate = sr_O)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Noisy data

# %%
y_N, sr_N = librosa.load('./Output/Noisy_dig110/Noisy_dig_110_Final.wav')

# %%
ipd.Audio(y_N,rate = sr_N)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Output

# %%
y_F, sr_F = librosa.load('./Output/Noisy_dig110/Output_dig_110_Final.wav')

# %%
ipd.Audio(y_F,rate = sr_F)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Example 2

# %% [markdown]
# #### Original

# %%
y_O, sr_O = librosa.load('./Output/noisy_diggy_2.wav')

# %%
ipd.Audio(y_O,rate = sr_O)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Noisy

# %%
y_N,sr_N = librosa.load('./Output/org_diggy_2.wav')

# %%
ipd.Audio(y_N,rate = sr_N)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Output

# %%
y_F, sr_F = librosa.load('./Output/output_diggy_2.wav')

# %%
ipd.Audio(y_F,rate = sr_F)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Epoch 60 for MEGAN trained on Classical Music with Audience Applause Noise

# %% [markdown]
# ##### Original

# %%
y_O,sr_O = librosa.load('./Output/Noisy_60/Original_60.wav')

# %%
ipd.Audio(y_O,rate = sr_O)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Noisy

# %%
y_N, sr_N = librosa.load('./Output/Noisy_60/Original_60.wav')

# %%
ipd.Audio(y_N,rate= sr_N)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Output

# %%
y_F, sr_F = librosa.load('./Output/Noisy_60/Output_60.wav')

# %%
ipd.Audio(y_F,rate = sr_F)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
